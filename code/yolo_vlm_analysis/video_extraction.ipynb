# %% [markdown]
# Load in Video

# %%
# !VIDEO_URL="https://www.youtube.com/watch?v=TQ3MWnfvzg0" && \
yt-dlp "$VIDEO_URL" \
  --download-sections "*00:00:20-00:01:07" \
  -f "bv[ext=mp4][vcodec^=avc1]+ba[ext=m4a][acodec^=mp4a]/best[ext=mp4]" \
  -o "videos/clip_20_to_107.%(ext)s" \
  --merge-output-format mp4
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TQ3MWnfvzg0
# [youtube] TQ3MWnfvzg0: Downloading webpage
# [youtube] TQ3MWnfvzg0: Downloading tv client config
# [youtube] TQ3MWnfvzg0: Downloading player ab11fe69-main
# [youtube] TQ3MWnfvzg0: Downloading tv player API JSON
# [youtube] TQ3MWnfvzg0: Downloading ios player API JSON
# [youtube] TQ3MWnfvzg0: Downloading m3u8 information
# [info] TQ3MWnfvzg0: Downloading 1 format(s): 299+140
# [info] TQ3MWnfvzg0: Downloading 1 time ranges: 20.0-67.0
# [download] Destination: videos/clip_20_to_107.mp4
# ...
